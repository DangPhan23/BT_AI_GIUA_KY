# %% [markdown]
# <a href="https://colab.research.google.com/github/DangPhan23/BT_AI_GIUA_KY/blob/main/Bai_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Kết nối  Google Drive với Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Khai báo các thư viện cho mô hình mạng neural 
from keras import losses
from os import listdir
from numpy import asarray,save
import numpy as np
from keras.utils import load_img,img_to_array,to_categorical
from keras.utils.image_utils import img_to_array
from keras.models import Sequential,Model
from keras.layers import Conv2D,Dense,Dropout,Normalization,MaxPooling2D,Input,Flatten,LeakyReLU
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
#Tải các tệp ảnh trong Google Drive lên Google Colab
folder ='/content/drive/MyDrive/AI/flowers/'
photos, labels = list(), list()
for file in listdir(folder):
  output= 0.0
  if file.startswith('Hoa_dao'):
    output= 1.0
  if file.startswith('Hoa_hong'):
    output= 2.0
  if file.startswith('Hoa_mai'):
    output= 3.0
  if file.startswith('Hoa_sen'):
    output= 4.0
  if file.startswith('Hoa_sung'):
    output= 5.0
  if file.startswith('Hoa_tulip'):
    output= 6.0
  photo = load_img(folder + file, target_size= (40,40))
  photo= img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos= asarray(photos)
labels= asarray(labels)
#Lưu file photos và labels vào Google Drive 
print(photos.shape, labels.shape)
save('/content/drive/MyDrive/AI/flowers/flowers_photos.npy',photos)
save('/content/drive/MyDrive/AI/flowers/flowers_labels.npy',labels)
# Out:
# (180, 40, 40, 3) (180,)

# %%
split_index = int(0.05 * len(photos))
x_train = photos[split_index:]
y_train = labels[split_index:]
x_test = photos[:split_index]
y_test =  labels[:split_index]
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (171, 40, 40, 3) (9, 40, 40, 3) (171,) (9,)

# %%
x_train = x_train.reshape(171, 40, 40, 3) 
x_train = x_train.astype('float32')/255

x_test = x_test.reshape(9, 40, 40, 3) #
x_test = x_test.astype('float32')/255

y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
#Xây dựng mô hình mạng CNN
model = Sequential()
## lop CNN1
model.add(Conv2D(32,kernel_size=(3,3), activation='linear', input_shape=(40, 40, 3), padding='same')) #32 lan tich chap
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))
## lop CNN2
model.add(Conv2D(64,(3,3),activation='linear',padding='same')) #64 lan tich chap
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))
## lop CNN3
model.add(Conv2D(128,(3,3),activation='linear',padding='same')) #128 lan tich chap
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))
## lop CNN4
model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(256, (3,3), activation = 'linear', padding = 'same'))#256 lan tich chap
model.add(LeakyReLU(alpha = 0.1))
## lop CNN5
model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(512, (3,3), activation = 'linear', padding = 'same'))#512 lan tich chap
model.add(LeakyReLU(alpha = 0.1))

#Đưa vào ANN để phân loại:
model.add(Flatten())
model.add(Dense(128,activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 40, 32)        896
#
#  leaky_re_lu (LeakyReLU)     (None, 40, 40, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20, 20, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 10, 10, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 256)         295168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 3, 3, 256)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 512)         1180160
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,832,138
# Trainable params: 1,832,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train model
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
history=model.fit(x_train, y_train, batch_size= 32, epochs= 50, verbose= 1)
# Out:
# Epoch 1/50
# 6/6 [==============================] - 4s 324ms/step - loss: 2.1108 - accuracy: 0.1520
# Epoch 2/50
# 6/6 [==============================] - 3s 465ms/step - loss: 1.9018 - accuracy: 0.1404
# Epoch 3/50
# 6/6 [==============================] - 2s 387ms/step - loss: 1.5637 - accuracy: 0.3392
# Epoch 4/50
# 6/6 [==============================] - 2s 290ms/step - loss: 1.3318 - accuracy: 0.4912
# Epoch 5/50
# 6/6 [==============================] - 2s 288ms/step - loss: 1.2560 - accuracy: 0.4386
# Epoch 6/50
# 6/6 [==============================] - 2s 286ms/step - loss: 1.0496 - accuracy: 0.5614
# Epoch 7/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.8642 - accuracy: 0.6199
# Epoch 8/50
# 6/6 [==============================] - 2s 286ms/step - loss: 0.7518 - accuracy: 0.6784
# Epoch 9/50
# 6/6 [==============================] - 3s 443ms/step - loss: 0.6358 - accuracy: 0.7427
# Epoch 10/50
# 6/6 [==============================] - 3s 483ms/step - loss: 0.5746 - accuracy: 0.7602
# Epoch 11/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.6365 - accuracy: 0.7368
# Epoch 12/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.4721 - accuracy: 0.8246
# Epoch 13/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.4650 - accuracy: 0.7895
# Epoch 14/50
# 6/6 [==============================] - 2s 283ms/step - loss: 0.3323 - accuracy: 0.8947
# Epoch 15/50
# 6/6 [==============================] - 2s 287ms/step - loss: 0.3549 - accuracy: 0.8655
# Epoch 16/50
# 6/6 [==============================] - 2s 345ms/step - loss: 0.2851 - accuracy: 0.8655
# Epoch 17/50
# 6/6 [==============================] - 3s 468ms/step - loss: 0.2349 - accuracy: 0.9181
# Epoch 18/50
# 6/6 [==============================] - 2s 322ms/step - loss: 0.1914 - accuracy: 0.9240
# Epoch 19/50
# 6/6 [==============================] - 2s 355ms/step - loss: 0.2502 - accuracy: 0.9181
# Epoch 20/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.1963 - accuracy: 0.9240
# Epoch 21/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.2135 - accuracy: 0.9181
# Epoch 22/50
# 6/6 [==============================] - 3s 530ms/step - loss: 0.1487 - accuracy: 0.9532
# Epoch 23/50
# 6/6 [==============================] - 3s 454ms/step - loss: 0.0663 - accuracy: 0.9942
# Epoch 24/50
# 6/6 [==============================] - 2s 324ms/step - loss: 0.0595 - accuracy: 0.9825
# Epoch 25/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.4828 - accuracy: 0.8947
# Epoch 26/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.2524 - accuracy: 0.9591
# Epoch 27/50
# 6/6 [==============================] - 2s 287ms/step - loss: 0.1067 - accuracy: 0.9766
# Epoch 28/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.0461 - accuracy: 0.9883
# Epoch 29/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.0286 - accuracy: 0.9942
# Epoch 30/50
# 6/6 [==============================] - 3s 481ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 31/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 32/50
# 6/6 [==============================] - 2s 287ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 33/50
# 6/6 [==============================] - 2s 295ms/step - loss: 7.4262e-04 - accuracy: 1.0000
# Epoch 34/50
# 6/6 [==============================] - 2s 294ms/step - loss: 6.2262e-04 - accuracy: 1.0000
# Epoch 35/50
# 6/6 [==============================] - 2s 294ms/step - loss: 5.1336e-04 - accuracy: 1.0000
# Epoch 36/50
# 6/6 [==============================] - 2s 308ms/step - loss: 4.0994e-04 - accuracy: 1.0000
# Epoch 37/50
# 6/6 [==============================] - 3s 470ms/step - loss: 3.4222e-04 - accuracy: 1.0000
# Epoch 38/50
# 6/6 [==============================] - 2s 347ms/step - loss: 2.9996e-04 - accuracy: 1.0000
# Epoch 39/50
# 6/6 [==============================] - 2s 292ms/step - loss: 2.6514e-04 - accuracy: 1.0000
# Epoch 40/50
# 6/6 [==============================] - 2s 290ms/step - loss: 2.4154e-04 - accuracy: 1.0000
# Epoch 41/50
# 6/6 [==============================] - 2s 298ms/step - loss: 2.2346e-04 - accuracy: 1.0000
# Epoch 42/50
# 6/6 [==============================] - 2s 289ms/step - loss: 2.0768e-04 - accuracy: 1.0000
# Epoch 43/50
# 6/6 [==============================] - 2s 293ms/step - loss: 1.9304e-04 - accuracy: 1.0000
# Epoch 44/50
# 6/6 [==============================] - 3s 563ms/step - loss: 1.8199e-04 - accuracy: 1.0000
# Epoch 45/50
# 6/6 [==============================] - 4s 631ms/step - loss: 1.7200e-04 - accuracy: 1.0000
# Epoch 46/50
# 6/6 [==============================] - 3s 513ms/step - loss: 1.6345e-04 - accuracy: 1.0000
# Epoch 47/50
# 6/6 [==============================] - 3s 532ms/step - loss: 1.5535e-04 - accuracy: 1.0000
# Epoch 48/50
# 6/6 [==============================] - 3s 491ms/step - loss: 1.4892e-04 - accuracy: 1.0000
# Epoch 49/50
# 6/6 [==============================] - 2s 392ms/step - loss: 1.4173e-04 - accuracy: 1.0000
# Epoch 50/50
# 6/6 [==============================] - 2s 289ms/step - loss: 1.3570e-04 - accuracy: 1.0000

# %%
#Biểu thị thông số lên biểu đồ
accuracy =history.history['accuracy']
loss = history.history['loss']
epochs=range(len(accuracy))
epochs=range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training accuracy', color='red')
plt.plot(epochs,loss , 'b', label ='Training loss')
plt.show()
# Out:
# <ipython-input-13-c59af3df7e75>:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, accuracy, 'b', label='Training accuracy', color='red')

# %%
#Kiểm tra độ chính xác và lưu model đã train vào Google Drive
model.save('/content/drive/MyDrive/AI/flowers/flowers.h5')
test_acc = model.evaluate(x_test,y_test)
print("Do chinh xac:  ",test_acc)
# Out:
# 1/1 [==============================] - 0s 226ms/step - loss: 0.1473 - accuracy: 0.8889
# Do chinh xac:   [0.14734092354774475, 0.8888888955116272]

# %%
#Test mô hình
folder = '/content/drive/MyDrive/AI/Test/Test_flowers/'
for file in listdir(folder):
  photo = load_img(folder  +  file)
  plt.imshow(photo)
  
  photo = load_img(folder +   file, target_size = (40, 40))
  photo=img_to_array(photo)
  photo=photo.astype('float32')
  photo=photo/255
  photo=np.expand_dims(photo,axis=0)
  result=(model.predict(photo).argmax())
  name_flowers=['','Hoa_dao', 'Hoa_hong', 'Hoa_mai', 'Hoa_sen', 'Hoa_sung', 'Hoa_tulip']
  print(name_flowers[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 130ms/step
# Hoa_hong
# 1/1 [==============================] - 0s 24ms/step
# Hoa_sung
# 1/1 [==============================] - 0s 37ms/step
# Hoa_mai
# 1/1 [==============================] - 0s 24ms/step
# Hoa_dao
# 1/1 [==============================] - 0s 23ms/step
# Hoa_tulip
# 1/1 [==============================] - 0s 23ms/step
# Hoa_sen
